# %%
import pymysql
import pandas as pd

conn = pymysql.connect(
    host='198.199.81.151',
    port=3306,
    user='zhanyl',
    passwd='qwerty',
    db='test',
    charset='utf8mb4')
print("connection successful!")
# Out:
# connection successful!

# %%
 df2 = pd.read_sql_query(
    "select FullNameRu from Minjust2018 limit 10",conn)
    
def find_related_companies_by_founders(companies_df, db_conn):
    founders=companies_df.iloc[:,1]
    founders_list=founders.values.toList()
    companiesList=list(map(find_companies_by_founders_string, founders_list)) 
    return companiesList

def find_companies_by_founders_string (founders_string,dbconn):
    listFounders= founders_string.split(',')
    companiesList=list(map(find_companiesByFounder,founderList))
    return companiesList

def find_companiesByFounder (founder, db_conn):
    df2 = pd.read_sql_query(
    "select FullNameRu from Minjust2018 where Founders like '%" + founder + "%' limit 10", db_conn)
    return df2

print(find_related_companies_by_founders(df2,conn))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-77-f077e6f776a8> in <module>()
#      18    return df2
#      19
# ---> 20 print(find_related_companies_by_founders(df2,conn))
#      21
#      22
#
# <ipython-input-77-f077e6f776a8> in find_related_companies_by_founders(companies_df, db_conn)
#       3
#       4 def find_related_companies_by_founders(companies_df, db_conn):
# ----> 5    founders=companies_df.iloc[:,1]
#       6    founders_list=founders.values.toList()
#       7    companiesList=list(map(find_companies_by_founders_string, founders_list))
#
# D:\miniconda\envs\mysqljypiter\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1470             except (KeyError, IndexError):
#    1471                 pass
# -> 1472             return self._getitem_tuple(key)
#    1473         else:
#    1474             # we by definition only have the 0th axis
#
# D:\miniconda\envs\mysqljypiter\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    2011     def _getitem_tuple(self, tup):
#    2012
# -> 2013         self._has_valid_tuple(tup)
#    2014         try:
#    2015             return self._getitem_lowerdim(tup)
#
# D:\miniconda\envs\mysqljypiter\lib\site-packages\pandas\core\indexing.py in _has_valid_tuple(self, key)
#     220                 raise IndexingError('Too many indexers')
#     221             try:
# --> 222                 self._validate_key(k, i)
#     223             except ValueError:
#     224                 raise ValueError("Location based indexing can only have "
#
# D:\miniconda\envs\mysqljypiter\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1955             return
#    1956         elif is_integer(key):
# -> 1957             self._validate_integer(key, axis)
#    1958         elif isinstance(key, tuple):
#    1959             # a tuple should already have been caught by this point
#
# D:\miniconda\envs\mysqljypiter\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    2007         l = len(ax)
#    2008         if key >= l or key < -l:
# -> 2009             raise IndexError("single positional indexer is out-of-bounds")
#    2010
#    2011     def _getitem_tuple(self, tup):
#
# IndexError: single positional indexer is out-of-bounds

# %%
def multiple2(n):
    return n*2
number_list= [1,5,4,9]
number_list_multiple= list(map(multiple2,number_list ))
print(number_list_multiple)
# Out:
# [2, 10, 8, 18]

# %%
print(plus2(9))
# Out:
# 11

# %%
def plus2(n):
    return(n+2)

# %%
df = pd.read_sql_query(
    "SELECT * FROM Minjust2018 LIMIT 0, 10",
    conn)
df.tail(10)
# Out:
#    id                Date  links_id  \
# 0   1 2018-03-04 18:45:04         2
# 1   2 2018-06-03 13:13:05         1
# 2   3 2018-06-03 13:13:12         2
# 3   4 2018-06-03 13:13:14         3
# 4   5 2018-06-03 13:13:16         4
# 5   6 2018-06-03 13:13:18         5
# 6   7 2018-06-03 13:13:19         6
# 7   8 2018-06-03 13:13:20         7
# 8   9 2018-06-03 13:13:21         8
# 9  10 2018-06-03 13:13:22         9
#
#                                           FullNameKy  \
# 0  "Казкоммерцбанк Кыргызстан" ачык акционердик к...
# 1  У-е " Центр спортивной медицины и реаблитации ...
# 2  "Казкоммерцбанк Кыргызстан" ачык акционердик к...
# 3                 "Алтынбек-Эркинбек" дыйкан чарбасы
# 4                                    ООО "Турандот"
# 5                     "Кызылтоо-Озгон" коомдук фонду
# 6                    ОФ "TOEFL CENTER" (Тоэфл центр)
# 7   "Кубанычбек Ата Кубансын" айыл чарба кооперативи
# 8     "Вербена" Турак жай менчик ээлеринин шериктиги
# 9                        "Лайф Плюс"  коомдук фонду
#
#                                           FullNameRu  \
# 0  Жалал-Абадский филиал открытого акционерного о...
# 1  У-е " Центр спортивной медицины и реаблитации ...
# 2  Жалал-Абадский филиал открытого акционерного о...
# 3        Крестиьянское хозяйство "Алтынбек-Эркинбек"
# 4                                    ООО "Турандот"
# 5                 Общественный фонд "Кызылтоо-Озгон"
# 6                    ОФ "TOEFL CENTER" (Тоэфл центр)
# 7  Сельскохозяйственный кооператив "Кубанычбек Ат...
# 8        Товарищество собственников жилья "Вербена"
# 9                   Обшественный фонд  "Лайф Плюс"
#
#                                          ShortNameKy  \
# 0                "Казкоммерцбанк Кыргызстан" ААК ЖАФ
# 1  У-е " Центр спортивной медицины и реаблитации ...
# 2                "Казкоммерцбанк Кыргызстан" ААК ЖАФ
# 3                                               None
# 4                                    ООО "Турандот"
# 5                                "Кызылтоо-Озгон" КФ
# 6                                               None
# 7                                               None
# 8                                    "Вербена" ТЖМЭШ
# 9                                   "Лайф Плюс"  КФ
#
#                                          ShortNameRu  \
# 0                ЖАФ ОАО "Казкоммерцбанк Кыргызстан"
# 1  У-е " Центр спортивной медицины и реаблитации ...
# 2                ЖАФ ОАО "Казкоммерцбанк Кыргызстан"
# 3                                               None
# 4                                    ООО "Турандот"
# 5                                ОФ "Кызылтоо-Озгон"
# 6                                               None
# 7                                               None
# 8                                      ТСЖ"Вербена"
# 9                                  ОФ  "Лайф Плюс"
#
#                                     OrgForm ForeignFounders        RegNumber  \
# 0                                   Филиал              нет  107596-3303-Ф-л
# 1                                Учреждение             нет  101128-3310-У-е
# 2                                   Филиал              нет  107596-3303-Ф-л
# 3       Крестьянское (фермерское) хозяйство             нет   102342-3306-КХ
# 4  Общество с ограниченной ответственностью             нет  100264-3310-ООО
# 5                         Общественный фонд             нет   102359-3306-ОФ
# 6                         Общественный фонд             нет    53413-3301-ОФ
# 7                   Коммерческий кооператив             нет   100327-3307-КК
# 8              Ассоциация водопользователей             нет   120546-3301-АВ
# 9                         Общественный фонд             нет   104986-3310-ОФ
#
#    ...  RegMethod  OwnershipForm                          HeadName  \
# 0  ...       None       Частная       Орозбаев Талантбек Жалилович
# 1  ...       None  Муниципальная     Школьников Николай Яковлевич
# 2  ...       None       Частная       Орозбаев Талантбек Жалилович
# 3  ...       None       Частная        Турдуев  Марипбай Маманович
# 4  ...       None       Частная   Кадырбекова Гулназ Сагындыковна
# 5  ...       None       Частная                  Тешебаев Назирбай
# 6  ...       None       Частная            Кулева Мария Тимофеевна
# 7  ...       None       Частная    Балапанов Талант Кубанычбекович
# 8  ...       None       Частная       Камкина Наталья Владимировна
# 9  ...       None       Частная           Галиева Алтынай Душаевна
#
#               MainActivity ActivityCode PhysFoundersNum JurFoundersNum  \
# 0  Предоставление кредитов         None               0              1
# 1                     None         None            None              1
# 2  Предоставление кредитов         None               0              1
# 3                     None         None               1           None
# 4                     None         None               1           None
# 5      благотворительность         None               1              0
# 6                     None         None               2              0
# 7                     None         None               7              1
# 8                     None         None              38              0
# 9        благотворительная         None               1              0
#
#   TotalFoundersNum                                           Founders Notes
# 0             None                                               None  None
# 1             None                                   Мэрия города Ош   None
# 2             None                                                     None
# 3             None                         Турдуев Марипбай Маманович  None
# 4             None                    Кадырбекова Гулназ Сагындыкова   None
# 5             None                                  Тешебаев Назирбай  None
# 6             None  Кулева Мария Тимофеевна, Рындина Светлана Серг...  None
# 7             None  Балапанов Талант Кубанычбекович, Балапанов Куб...  None
# 8             None                    согласно представленного списка  None
# 9             None                          Галиева Алтынай Душаевна   None
#
# [10 rows x 35 columns]

# %%
conn.close()
print("connection closed")
# Out:
# connection closed

# %%
df = pd.read_sql_query(
    "select Minjust2018.HeadName, Minjust2018.Founders, Minjust2018.FullNameRu, persons.fullName, persons.inn from persons join Minjust2018 on persons.fullName LIKE  CONCAT('%', Minjust2018.HeadName, '%') or persons.fullName LIKE  CONCAT('%', Minjust2018.Founders,'%') WHERE (persons.inn REGEXP '([1-2][0-9][0-9][0-9][0-9])([1][9][9][7-9])|([2][0][0][0-9])*') limit 10",
    conn)
df.tail(10)
# Out:
#                             HeadName Founders  \
# 0       Орозбаев Талантбек Жалилович
# 1                               None
# 2                               None
# 3           Чормопов Мелис Бакасович
# 4    Жунусалиев Алтынбек Аданбекович
# 5     Решетникова Наталья Николаевна
# 6      Аллашукурова Ирина Николаевна
# 7                       М.А. Шопоков
# 8          Попов Владимир Михайлович
# 9  Ибраимова Сабыркуль Абдурасуловна
#
#                                           FullNameRu  \
# 0  Жалал-Абадский филиал открытого акционерного о...
# 1  Сельскохозяйственный семеноводческий кооперати...
# 2        Объединение крестьянских хозяйств "Кой-Таш"
# 3                 Малое предприятие Фирма "Квадрига"
# 4  АОЗТ "7Ж" (уведомление о смене руков. от 28.11...
# 5                                     ОсОО "Кубаныч"
# 6  Кыргызско-Российское совместное предприятие "А...
# 7  Ассоциация крестьянских хозяйств "Шалта" (юр. ...
# 8             Закрытое акционерное общество "ТЕХКОМ"
# 9                              Ысык-Атинское районо.
#
#                               fullName             inn
# 0  Джолдошбекова Айсезим Таалайбековна  12112199401001
# 1  Джолдошбекова Айсезим Таалайбековна  12112199401001
# 2  Джолдошбекова Айсезим Таалайбековна  12112199401001
# 3  Джолдошбекова Айсезим Таалайбековна  12112199401001
# 4  Джолдошбекова Айсезим Таалайбековна  12112199401001
# 5  Джолдошбекова Айсезим Таалайбековна  12112199401001
# 6  Джолдошбекова Айсезим Таалайбековна  12112199401001
# 7  Джолдошбекова Айсезим Таалайбековна  12112199401001
# 8  Джолдошбекова Айсезим Таалайбековна  12112199401001
# 9  Джолдошбекова Айсезим Таалайбековна  12112199401001

# %%
df = pd.read_sql_query(
    "select Minjust2018.HeadName, Minjust2018.Founders, Minjust2018.FullNameRu, persons.fullName, persons.inn from persons join Minjust2018 on persons.fullName LIKE CONCAT('%', Minjust2018.HeadName, '%') or persons.fullName LIKE CONCAT('%', Minjust2018.Founders,'%') WHERE (Year(CURDATE())- SUBSTRING(persons.inn, 6, 4)<21 And (persons.inn like '1%' or persons.inn like '2%')) limit 10", conn)
df.tail(10)
# Out:
#                             HeadName Founders  \
# 0       Орозбаев Талантбек Жалилович
# 1                               None
# 2                               None
# 3           Чормопов Мелис Бакасович
# 4    Жунусалиев Алтынбек Аданбекович
# 5     Решетникова Наталья Николаевна
# 6      Аллашукурова Ирина Николаевна
# 7                       М.А. Шопоков
# 8          Попов Владимир Михайлович
# 9  Ибраимова Сабыркуль Абдурасуловна
#
#                                           FullNameRu  \
# 0  Жалал-Абадский филиал открытого акционерного о...
# 1  Сельскохозяйственный семеноводческий кооперати...
# 2        Объединение крестьянских хозяйств "Кой-Таш"
# 3                 Малое предприятие Фирма "Квадрига"
# 4  АОЗТ "7Ж" (уведомление о смене руков. от 28.11...
# 5                                     ОсОО "Кубаныч"
# 6  Кыргызско-Российское совместное предприятие "А...
# 7  Ассоциация крестьянских хозяйств "Шалта" (юр. ...
# 8             Закрытое акционерное общество "ТЕХКОМ"
# 9                              Ысык-Атинское районо.
#
#                            fullName             inn
# 0  Иманалиева Айсулуу Таалайбековна  11412199801024
# 1  Иманалиева Айсулуу Таалайбековна  11412199801024
# 2  Иманалиева Айсулуу Таалайбековна  11412199801024
# 3  Иманалиева Айсулуу Таалайбековна  11412199801024
# 4  Иманалиева Айсулуу Таалайбековна  11412199801024
# 5  Иманалиева Айсулуу Таалайбековна  11412199801024
# 6  Иманалиева Айсулуу Таалайбековна  11412199801024
# 7  Иманалиева Айсулуу Таалайбековна  11412199801024
# 8  Иманалиева Айсулуу Таалайбековна  11412199801024
# 9  Иманалиева Айсулуу Таалайбековна  11412199801024

# %%
df = pd.read_sql_query(
    "select Minjust2018.HeadName, Minjust2018.Founders, Minjust2018.FullNameRu, persons.fullName, persons.inn from persons join Minjust2018 on persons.fullName LIKE CONCAT('%', Minjust2018.HeadName, '%') or persons.fullName LIKE CONCAT('%', Minjust2018.Founders,'%') WHERE (Year(CURDATE())- SUBSTRING(persons.inn, 6, 4)<21 And (persons.inn like '1%' or persons.inn like '2%')) limit 10", conn)
df.iloc[2,3]
# Out:
# 'Иманалиева Айсулуу Таалайбековна'

# %%
df = pd.read_sql_query(
    "select Founders, FullNameRu from Minjust2018 limit 100", conn)
df.iloc[7,0]
# Out:
# 'Балапанов Талант Кубанычбекович, Балапанов Кубанычбек Кукумбаевич, Бейшеналиева Алиакул, Кошалиев Омор Касымович, Балапанов Бакыт Кубанычбекович, Турсалиева Гульбар Ергешовна, Султанова Кылым Джорупбековна'

# %%
df = pd.read_sql_query(
    "select Founders, FullNameRu from Minjust2018 limit 10", conn)
founders=df.iloc[7,0]
founders_list = founders.split(',')
a=founders_list[1]

df2 = find_companiesByFounder(a,conn)
df2.tail(10)
# Out:
#                                           FullNameRu
# 0  Сельскохозяйственный кооператив "Кубанычбек Ат...

# %% [markdown]
# Вывод людей младше 21, имеющих бизнес в КР

# %%
df = pd.read_sql_query(
    "SELECT declaration.positn, declaration.first_name,declaration.middle_name,declaration.last_name, declaration.income_sum, bulgarien_prop.adress as 'адрес в Болгарии' from declaration join bulgarien_prop on bulgarien_prop.name_Ru like CONCAT('%', declaration.last_name,'%') where bulgarien_prop.property LIKE 'YES' limit 100", conn)
df.tail(10)
# Out:
#                               positn first_name     middle_name     last_name  \
# 28                           Эксперт      Асель     Омурбековна  Бейшеналиева
# 29                           Эксперт      Асель     Омурбековна  Бейшеналиева
# 30               Заведующий сектором    Жетиген       Жокинович       Бакиров
# 31               Заведующий сектором    Жетиген       Жокинович       Бакиров
# 32                         Инспектор  Амангелди  Сайдимаматович       Бакиров
# 33                         Инспектор  Амангелди  Сайдимаматович       Бакиров
# 34             Руководитель аппарата  Кайратбек    Муратбекович        Асанов
# 35                               Мэр      Болот        Саякович       Бакиров
# 36                               Мэр      Болот        Саякович       Бакиров
# 37  Пресс-секретарь премьер-министра   Бакытбек    Сарбагышович        Асанов
#
#     income_sum                                   адрес в Болгарии
# 28      596642  ( Физическо лице - субект на Булстат) адрес:(с...
# 29      596642  ( Физическо лице - субект на Булстат) адрес:(с...
# 30      622686
# 31      622686  ( Физическо лице - субект на Булстат) адрес:(с...
# 32      919689
# 33      919689  ( Физическо лице - субект на Булстат) адрес:(с...
# 34      342536  ( Физическо лице - субект на Булстат) адрес:(с...
# 35      368328
# 36      368328  ( Физическо лице - субект на Булстат) адрес:(с...
# 37      615570  ( Физическо лице - субект на Булстат) адрес:(с...

# %% [markdown]
# Список людей, занимающих должность в правительстве, имеющих имущество в Болгарии
